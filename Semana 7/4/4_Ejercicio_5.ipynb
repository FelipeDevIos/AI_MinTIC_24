# %%
import keras
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

import pandas as pd
import matplotlib.pyplot as plt

# %%
# Cargar el conjunto de datos
housing = fetch_california_housing()

# %%
housing.data
# Out:
# array([[   8.3252    ,   41.        ,    6.98412698, ...,    2.55555556,
#           37.88      , -122.23      ],
#        [   8.3014    ,   21.        ,    6.23813708, ...,    2.10984183,
#           37.86      , -122.22      ],
#        [   7.2574    ,   52.        ,    8.28813559, ...,    2.80225989,
#           37.85      , -122.24      ],
#        ...,
#        [   1.7       ,   17.        ,    5.20554273, ...,    2.3256351 ,
#           39.43      , -121.22      ],
#        [   1.8672    ,   18.        ,    5.32951289, ...,    2.12320917,
#           39.43      , -121.32      ],
#        [   2.3886    ,   16.        ,    5.25471698, ...,    2.61698113,
#           39.37      , -121.24      ]])

# %%
# Crear el conjunto de datos de entrenamiento, validación y prueba
X_train_full, X_test, y_train_full, y_test = train_test_split(housing.data, housing.target)
X_train, X_valid, y_train, y_valid = train_test_split(X_train_full, y_train_full)

print('X_train:', X_train.shape)
print('X_test:', X_test.shape)
print('X_valid:', X_valid.shape)
print('y_train:', y_train.shape)
print('y_test:', y_test.shape)
print('y_valid:', y_valid.shape)
# Out:
# X_train: (11610, 8)
# X_test: (5160, 8)
# X_valid: (3870, 8)
# y_train: (11610,)
# y_test: (5160,)
# y_valid: (3870,)

# %%
# Escalar los datos
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
X_valid = scaler.transform(X_valid)

# %%
# crear el modelo de red neuronal:

model = keras.models.Sequential([
    keras.layers.Dense(30, activation="relu", input_shape=X_train.shape[1:]),
    keras.layers.Dense(1)])

# %%
model.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_18 (Dense)            (None, 30)                270
#
#  dense_19 (Dense)            (None, 1)                 31
#
# =================================================================
# Total params: 301 (1.18 KB)
# Trainable params: 301 (1.18 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compilar el modelo

model.compile(loss="mean_squared_error",
              optimizer='sgd',
              metrics = [keras.metrics.RootMeanSquaredError(),
                         'mean_absolute_percentage_error'])

# %%
# Entrenar el modelo
history = model.fit(X_train, y_train, epochs=50,
                    validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/50
# 363/363 [==============================] - 2s 4ms/step - loss: 0.9912 - root_mean_squared_error: 0.9956 - mean_absolute_percentage_error: 39.7701 - val_loss: 3.0734 - val_root_mean_squared_error: 1.7531 - val_mean_absolute_percentage_error: 35.3481
# Epoch 2/50
# 363/363 [==============================] - 1s 3ms/step - loss: 0.6847 - root_mean_squared_error: 0.8274 - mean_absolute_percentage_error: 32.2023 - val_loss: 0.5111 - val_root_mean_squared_error: 0.7149 - val_mean_absolute_percentage_error: 30.1526
# Epoch 3/50
# 363/363 [==============================] - 1s 3ms/step - loss: 0.4986 - root_mean_squared_error: 0.7061 - mean_absolute_percentage_error: 29.5127 - val_loss: 0.4596 - val_root_mean_squared_error: 0.6779 - val_mean_absolute_percentage_error: 27.1228
# Epoch 4/50
# 363/363 [==============================] - 1s 3ms/step - loss: 0.4542 - root_mean_squared_error: 0.6739 - mean_absolute_percentage_error: 27.6274 - val_loss: 0.4394 - val_root_mean_squared_error: 0.6629 - val_mean_absolute_percentage_error: 25.8518
# Epoch 5/50
# 363/363 [==============================] - 1s 3ms/step - loss: 0.4324 - root_mean_squared_error: 0.6576 - mean_absolute_percentage_error: 26.7150 - val_loss: 0.4202 - val_root_mean_squared_error: 0.6482 - val_mean_absolute_percentage_error: 25.3770
# Epoch 6/50
# 363/363 [==============================] - 1s 2ms/step - loss: 0.4390 - root_mean_squared_error: 0.6625 - mean_absolute_percentage_error: 26.4129 - val_loss: 0.4165 - val_root_mean_squared_error: 0.6453 - val_mean_absolute_percentage_error: 26.5770
# Epoch 7/50
# 363/363 [==============================] - 1s 3ms/step - loss: 0.4158 - root_mean_squared_error: 0.6448 - mean_absolute_percentage_error: 25.8516 - val_loss: 0.4052 - val_root_mean_squared_error: 0.6366 - val_mean_absolute_percentage_error: 25.1565
# Epoch 8/50
# 363/363 [==============================] - 1s 2ms/step - loss: 0.4258 - root_mean_squared_error: 0.6525 - mean_absolute_percentage_error: 25.8832 - val_loss: 0.4124 - val_root_mean_squared_error: 0.6422 - val_mean_absolute_percentage_error: 26.2739
# Epoch 9/50
# 363/363 [==============================] - 1s 3ms/step - loss: 0.4049 - root_mean_squared_error: 0.6363 - mean_absolute_percentage_error: 25.5454 - val_loss: 0.3906 - val_root_mean_squared_error: 0.6250 - val_mean_absolute_percentage_error: 24.4177
# Epoch 10/50
# 363/363 [==============================] - 2s 5ms/step - loss: 0.4000 - root_mean_squared_error: 0.6325 - mean_absolute_percentage_error: 25.3385 - val_loss: 0.3905 - val_root_mean_squared_error: 0.6249 - val_mean_absolute_percentage_error: 25.3201
# Epoch 11/50
# 363/363 [==============================] - 2s 5ms/step - loss: 0.3965 - root_mean_squared_error: 0.6297 - mean_absolute_percentage_error: 25.2501 - val_loss: 0.3884 - val_root_mean_squared_error: 0.6232 - val_mean_absolute_percentage_error: 24.1025
# Epoch 12/50
# 363/363 [==============================] - 1s 3ms/step - loss: 0.3932 - root_mean_squared_error: 0.6270 - mean_absolute_percentage_error: 25.0546 - val_loss: 0.3877 - val_root_mean_squared_error: 0.6227 - val_mean_absolute_percentage_error: 24.8572
# Epoch 13/50
# 363/363 [==============================] - 1s 3ms/step - loss: 0.3894 - root_mean_squared_error: 0.6240 - mean_absolute_percentage_error: 25.0011 - val_loss: 0.3898 - val_root_mean_squared_error: 0.6243 - val_mean_absolute_percentage_error: 25.0457
# Epoch 14/50
# 363/363 [==============================] - 1s 3ms/step - loss: 0.3880 - root_mean_squared_error: 0.6229 - mean_absolute_percentage_error: 24.9527 - val_loss: 0.3796 - val_root_mean_squared_error: 0.6161 - val_mean_absolute_percentage_error: 25.0482
# Epoch 15/50
# 363/363 [==============================] - 1s 3ms/step - loss: 0.3845 - root_mean_squared_error: 0.6201 - mean_absolute_percentage_error: 24.8935 - val_loss: 0.3768 - val_root_mean_squared_error: 0.6138 - val_mean_absolute_percentage_error: 22.7003
# Epoch 16/50
# 363/363 [==============================] - 1s 3ms/step - loss: 0.3822 - root_mean_squared_error: 0.6182 - mean_absolute_percentage_error: 24.6383 - val_loss: 0.3833 - val_root_mean_squared_error: 0.6191 - val_mean_absolute_percentage_error: 24.4120
# Epoch 17/50
# 363/363 [==============================] - 1s 3ms/step - loss: 0.3794 - root_mean_squared_error: 0.6160 - mean_absolute_percentage_error: 24.6363 - val_loss: 0.3676 - val_root_mean_squared_error: 0.6063 - val_mean_absolute_percentage_error: 24.9343
# Epoch 18/50
# 363/363 [==============================] - 1s 3ms/step - loss: 0.3761 - root_mean_squared_error: 0.6133 - mean_absolute_percentage_error: 24.5149 - val_loss: 0.3944 - val_root_mean_squared_error: 0.6281 - val_mean_absolute_percentage_error: 25.2872
# Epoch 19/50
# 363/363 [==============================] - 1s 2ms/step - loss: 0.3783 - root_mean_squared_error: 0.6150 - mean_absolute_percentage_error: 24.5151 - val_loss: 0.3715 - val_root_mean_squared_error: 0.6095 - val_mean_absolute_percentage_error: 24.7808
# Epoch 20/50
# 363/363 [==============================] - 1s 2ms/step - loss: 0.3758 - root_mean_squared_error: 0.6130 - mean_absolute_percentage_error: 24.4660 - val_loss: 0.3687 - val_root_mean_squared_error: 0.6072 - val_mean_absolute_percentage_error: 23.6109
# Epoch 21/50
# 363/363 [==============================] - 1s 2ms/step - loss: 0.3714 - root_mean_squared_error: 0.6094 - mean_absolute_percentage_error: 24.3474 - val_loss: 0.3599 - val_root_mean_squared_error: 0.5999 - val_mean_absolute_percentage_error: 23.5327
# Epoch 22/50
# 363/363 [==============================] - 2s 5ms/step - loss: 0.3718 - root_mean_squared_error: 0.6097 - mean_absolute_percentage_error: 24.2866 - val_loss: 0.3792 - val_root_mean_squared_error: 0.6158 - val_mean_absolute_percentage_error: 24.9584
# Epoch 23/50
# 363/363 [==============================] - 1s 4ms/step - loss: 0.3696 - root_mean_squared_error: 0.6080 - mean_absolute_percentage_error: 24.2481 - val_loss: 0.3613 - val_root_mean_squared_error: 0.6011 - val_mean_absolute_percentage_error: 23.1881
# Epoch 24/50
# 363/363 [==============================] - 1s 3ms/step - loss: 0.3658 - root_mean_squared_error: 0.6048 - mean_absolute_percentage_error: 24.1162 - val_loss: 0.3745 - val_root_mean_squared_error: 0.6119 - val_mean_absolute_percentage_error: 24.4331
# Epoch 25/50
# 363/363 [==============================] - 1s 3ms/step - loss: 0.3643 - root_mean_squared_error: 0.6036 - mean_absolute_percentage_error: 24.0514 - val_loss: 0.3574 - val_root_mean_squared_error: 0.5979 - val_mean_absolute_percentage_error: 24.4994
# Epoch 26/50
# 363/363 [==============================] - 1s 3ms/step - loss: 0.3633 - root_mean_squared_error: 0.6027 - mean_absolute_percentage_error: 24.0993 - val_loss: 0.3816 - val_root_mean_squared_error: 0.6177 - val_mean_absolute_percentage_error: 23.2641
# Epoch 27/50
# 363/363 [==============================] - 1s 3ms/step - loss: 0.3630 - root_mean_squared_error: 0.6025 - mean_absolute_percentage_error: 24.0066 - val_loss: 0.3538 - val_root_mean_squared_error: 0.5948 - val_mean_absolute_percentage_error: 24.3955
# Epoch 28/50
# 363/363 [==============================] - 1s 3ms/step - loss: 0.3596 - root_mean_squared_error: 0.5997 - mean_absolute_percentage_error: 24.0560 - val_loss: 0.3518 - val_root_mean_squared_error: 0.5931 - val_mean_absolute_percentage_error: 23.4558
# Epoch 29/50
# 363/363 [==============================] - 1s 3ms/step - loss: 0.3587 - root_mean_squared_error: 0.5989 - mean_absolute_percentage_error: 23.9140 - val_loss: 0.3609 - val_root_mean_squared_error: 0.6007 - val_mean_absolute_percentage_error: 23.7549
# Epoch 30/50
# 363/363 [==============================] - 1s 3ms/step - loss: 0.3619 - root_mean_squared_error: 0.6016 - mean_absolute_percentage_error: 24.0179 - val_loss: 0.3522 - val_root_mean_squared_error: 0.5935 - val_mean_absolute_percentage_error: 23.0527
# Epoch 31/50
# 363/363 [==============================] - 1s 3ms/step - loss: 0.3629 - root_mean_squared_error: 0.6024 - mean_absolute_percentage_error: 23.9784 - val_loss: 0.3492 - val_root_mean_squared_error: 0.5909 - val_mean_absolute_percentage_error: 24.2679
# Epoch 32/50
# 363/363 [==============================] - 1s 3ms/step - loss: 0.3560 - root_mean_squared_error: 0.5967 - mean_absolute_percentage_error: 23.8612 - val_loss: 0.3497 - val_root_mean_squared_error: 0.5914 - val_mean_absolute_percentage_error: 24.1648
# Epoch 33/50
# 363/363 [==============================] - 1s 3ms/step - loss: 0.3559 - root_mean_squared_error: 0.5966 - mean_absolute_percentage_error: 23.8089 - val_loss: 0.3427 - val_root_mean_squared_error: 0.5854 - val_mean_absolute_percentage_error: 24.0472
# Epoch 34/50
# 363/363 [==============================] - 2s 5ms/step - loss: 0.3546 - root_mean_squared_error: 0.5955 - mean_absolute_percentage_error: 23.7949 - val_loss: 0.3458 - val_root_mean_squared_error: 0.5880 - val_mean_absolute_percentage_error: 22.7846
# Epoch 35/50
# 363/363 [==============================] - 1s 4ms/step - loss: 0.3519 - root_mean_squared_error: 0.5932 - mean_absolute_percentage_error: 23.7113 - val_loss: 0.3722 - val_root_mean_squared_error: 0.6100 - val_mean_absolute_percentage_error: 23.2149
# Epoch 36/50
# 363/363 [==============================] - 1s 3ms/step - loss: 0.3548 - root_mean_squared_error: 0.5957 - mean_absolute_percentage_error: 23.8180 - val_loss: 0.3435 - val_root_mean_squared_error: 0.5861 - val_mean_absolute_percentage_error: 24.4285
# Epoch 37/50
# 363/363 [==============================] - 1s 3ms/step - loss: 0.3495 - root_mean_squared_error: 0.5912 - mean_absolute_percentage_error: 23.6916 - val_loss: 0.3426 - val_root_mean_squared_error: 0.5853 - val_mean_absolute_percentage_error: 23.7032
# Epoch 38/50
# 363/363 [==============================] - 1s 3ms/step - loss: 0.3475 - root_mean_squared_error: 0.5895 - mean_absolute_percentage_error: 23.6659 - val_loss: 0.3545 - val_root_mean_squared_error: 0.5954 - val_mean_absolute_percentage_error: 24.0210
# Epoch 39/50
# 363/363 [==============================] - 1s 3ms/step - loss: 0.3529 - root_mean_squared_error: 0.5940 - mean_absolute_percentage_error: 23.7364 - val_loss: 0.3406 - val_root_mean_squared_error: 0.5836 - val_mean_absolute_percentage_error: 24.4602
# Epoch 40/50
# 363/363 [==============================] - 1s 3ms/step - loss: 0.3461 - root_mean_squared_error: 0.5883 - mean_absolute_percentage_error: 23.6847 - val_loss: 0.3372 - val_root_mean_squared_error: 0.5807 - val_mean_absolute_percentage_error: 22.2998
# Epoch 41/50
# 363/363 [==============================] - 1s 3ms/step - loss: 0.3469 - root_mean_squared_error: 0.5890 - mean_absolute_percentage_error: 23.6037 - val_loss: 0.3709 - val_root_mean_squared_error: 0.6090 - val_mean_absolute_percentage_error: 24.0572
# Epoch 42/50
# 363/363 [==============================] - 1s 3ms/step - loss: 0.3464 - root_mean_squared_error: 0.5886 - mean_absolute_percentage_error: 23.5940 - val_loss: 0.3382 - val_root_mean_squared_error: 0.5815 - val_mean_absolute_percentage_error: 23.8248
# Epoch 43/50
# 363/363 [==============================] - 1s 3ms/step - loss: 0.3443 - root_mean_squared_error: 0.5867 - mean_absolute_percentage_error: 23.5123 - val_loss: 0.3879 - val_root_mean_squared_error: 0.6228 - val_mean_absolute_percentage_error: 23.6568
# Epoch 44/50
# 363/363 [==============================] - 1s 3ms/step - loss: 0.3517 - root_mean_squared_error: 0.5931 - mean_absolute_percentage_error: 23.5903 - val_loss: 0.5456 - val_root_mean_squared_error: 0.7386 - val_mean_absolute_percentage_error: 25.0680
# Epoch 45/50
# 363/363 [==============================] - 2s 5ms/step - loss: 0.3614 - root_mean_squared_error: 0.6012 - mean_absolute_percentage_error: 23.7189 - val_loss: 0.3331 - val_root_mean_squared_error: 0.5772 - val_mean_absolute_percentage_error: 23.1460
# Epoch 46/50
# 363/363 [==============================] - 2s 5ms/step - loss: 0.3459 - root_mean_squared_error: 0.5882 - mean_absolute_percentage_error: 23.5459 - val_loss: 0.3664 - val_root_mean_squared_error: 0.6053 - val_mean_absolute_percentage_error: 24.6178
# Epoch 47/50
# 363/363 [==============================] - 1s 3ms/step - loss: 0.3459 - root_mean_squared_error: 0.5882 - mean_absolute_percentage_error: 23.6263 - val_loss: 0.3422 - val_root_mean_squared_error: 0.5850 - val_mean_absolute_percentage_error: 22.3405
# Epoch 48/50
# 363/363 [==============================] - 1s 3ms/step - loss: 0.3403 - root_mean_squared_error: 0.5833 - mean_absolute_percentage_error: 23.4716 - val_loss: 0.3403 - val_root_mean_squared_error: 0.5834 - val_mean_absolute_percentage_error: 23.4963
# Epoch 49/50
# 363/363 [==============================] - 1s 3ms/step - loss: 0.3390 - root_mean_squared_error: 0.5823 - mean_absolute_percentage_error: 23.4415 - val_loss: 0.3399 - val_root_mean_squared_error: 0.5830 - val_mean_absolute_percentage_error: 23.1285
# Epoch 50/50
# 363/363 [==============================] - 1s 3ms/step - loss: 0.3411 - root_mean_squared_error: 0.5841 - mean_absolute_percentage_error: 23.4714 - val_loss: 0.3412 - val_root_mean_squared_error: 0.5841 - val_mean_absolute_percentage_error: 22.7464

# %%
# Graficar el historial de entrenamiento
dfHistory = pd.DataFrame(history.history)
dfHistory[['loss', 'val_loss', 'root_mean_squared_error', 'val_root_mean_squared_error']].plot(grid=True)
dfHistory[['mean_absolute_percentage_error', 'val_mean_absolute_percentage_error']].plot(grid=True)
# Out:
# <Axes: >

# %%
# Evaluar el modelo en el conjunto de entrenamiento
loss, RMSE, MAPE = model.evaluate(X_train, y_train)
print('Evaluar el modelo en el conjunto de entrenamiento')
print('loss train:', loss)
print('root_mean_squared_error train:', RMSE)
print('mean_absolute_percentage_error train:', MAPE)

# Evaluar el modelo en el conjunto de validacion
loss, RMSE, MAPE = model.evaluate(X_valid, y_valid)
print('Evaluar el modelo en el conjunto de validacion')
print('loss valid:', loss)
print('root_mean_squared_error valid:', RMSE)
print('mean_absolute_percentage_error valid:', MAPE)

# Evaluar el modelo en el conjunto de prueba
loss, RMSE, MAPE = model.evaluate(X_test, y_test)
print('Evaluar el modelo en el conjunto de prueba')
print('loss test:', loss)
print('root_mean_squared_error test:', RMSE)
print('mean_absolute_percentage_error test:', MAPE)
# Out:
# 363/363 [==============================] - 1s 2ms/step - loss: 0.3344 - root_mean_squared_error: 0.5783 - mean_absolute_percentage_error: 22.9365
# Evaluar el modelo en el conjunto de entrenamiento
# loss train: 0.3344368636608124
# root_mean_squared_error train: 0.578305184841156
# mean_absolute_percentage_error train: 22.936519622802734
# 121/121 [==============================] - 0s 2ms/step - loss: 0.3412 - root_mean_squared_error: 0.5841 - mean_absolute_percentage_error: 22.7464
# Evaluar el modelo en el conjunto de validacion
# loss valid: 0.3411719501018524
# root_mean_squared_error valid: 0.584099292755127
# mean_absolute_percentage_error valid: 22.746423721313477
# 162/162 [==============================] - 0s 3ms/step - loss: 0.3193 - root_mean_squared_error: 0.5650 - mean_absolute_percentage_error: 22.6423
# Evaluar el modelo en el conjunto de prueba
# loss test: 0.3192640542984009
# root_mean_squared_error test: 0.5650345683097839
# mean_absolute_percentage_error test: 22.64225196838379

# %% [markdown]
# ## Preguntas
#
# ## Qué conjunto de datos se utilza en este codigo y que problema de aprendizaje automatico se aborda?
#
# Conjunto de datos es relacionado a viviendas de California. Se aborda un problema de regresión
#
# ## Qué hace la función train_test_split() de scikit-learn y por qué se utiliza en este código?
#
# La función train_test_split() de la biblioteca scikit-learn se utiliza para dividir un conjunto de datos en dos subconjuntos: uno para entrenamiento y otro para prueba (testing). Esto es esencial en el aprendizaje automático porque permite evaluar el rendimiento del modelo en datos no vistos durante el entrenamiento, lo cual es fundamental para medir la capacidad de generalización del modelo.
#
# Se utiliza para definir las variables referencia para el entrenamiento del modeo: X_train_full, X_test, y_train_full, y_test
#
# ## Por qué es importante estandarizar los datos antes de entrenar un modelo de redes neuronales?
#
# Los datos se estandarizan por:
#
# 1. Convergencia más rápida y estable: Las redes neuronales se entrenan utilizando algoritmos de optimización como el gradiente descendente. Estos algoritmos funcionan mejor cuando las características de entrada están en escalas similares. Estandarizar los datos (es decir, hacer que tengan una media de 0 y una desviación estándar de 1) ayuda a que el gradiente descendente converja más rápidamente y de manera más estable.
#
# 2. Evitar que algunas características dominen: Si las características tienen diferentes escalas, las que tienen valores más grandes pueden dominar el proceso de entrenamiento, lo que lleva a que el modelo aprenda más sobre esas características y menos sobre las otras. Esto puede resultar en un modelo sesgado y menos preciso.
#
# 3. Mejorar el rendimiento del modelo: Las redes neuronales suelen funcionar mejor cuando las entradas están estandarizadas. Esto es especialmente importante para capas que utilizan funciones de activación como ReLU o Sigmoid, que pueden saturarse y volverse menos sensibles a las entradas si estas no están en un rango adecuado.
#
# 4. Facilitar el entrenamiento y la generalización: Estandarizar los datos puede ayudar a que el modelo aprenda de manera más efectiva y generalice mejor a datos no vistos. Esto se debe a que la estandarización puede reducir el riesgo de sobreajuste, ya que el modelo no tendrá que adaptarse a escalas de características dispares.
#
# ## Qué arquitectura de red neuronal se utiliza en este código y cuántas capas tiene?
#
# Arquitectura de la Red Neuronal
#
# * Capa de entrada: La red no tiene explícitamente una capa de entrada  definida, pero la primera capa densa (Dense) actúa como tal. Se define con el parámetro input_shape, que indica la forma de los datos de entrada.
# * Primera capa oculta: Una capa densa (Dense) con 30 neuronas y la función de activación ReLU (relu).
# * Capa de salida: Una capa densa (Dense) con una sola neurona y sin función de activación especificada (lo que implica una activación lineal por defecto).
#
# Detalle de la Arquitectura
#
# * Número de capas: El modelo tiene un total de 2 capas densas.
# ** Primera capa oculta: 30 neuronas con activación ReLU.
# ** Capa de salida: 1 neurona con activación lineal (por defecto).
#
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 30)                270
#
#  dense_1 (Dense)             (None, 1)                 31
#
# =================================================================
# Total params: 301 (1.18 KB)
# Trainable params: 301 (1.18 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
#
# ## Qué funcion de activación se utiliza en la capa oculta de la red neuronal y por qué se elige esa función?
#
# ReLU, Rectified Linear Unit. Se usa por:
# * Aceleración del Entrenamiento: ReLU permite que las redes converjan más rápido en comparación con las funciones de activación sigmoide o tanh debido a sus propiedades de gradiente y sparsity.
# * Simplicidad y Eficiencia Computacional: La función ReLU es definida como $$ ReLU(x)=max⁡(0,x) $$. Esta operación es computacionalmente barata y fácil de implementar, lo que la hace eficiente en términos de tiempo de cálculo.
#
# ## Qué función de perdida se utiliza para compilar el modelo y qué métricas se utilizan para evaluar su rendimiento?
#
# Se utiliza la función de pérdida mean squared error (MSE) para compilar el modelo. En este caso, la pérdida MSE se define como el promedio de los cuadrados de las diferencias entre las predicciones del modelo y los valores reales.
#
# La elección de **MSE** como función de pérdida es apropiada para problemas de regresión porque:
#
# * Penaliza más fuertemente los errores grandes en comparación con los errores pequeños debido a la naturaleza cuadrática de la fórmula.
# * Es fácil de derivar y utilizar en algoritmos de optimización como el descenso de gradiente.
#
# **Métricas de rendimiento**
#
# 1. Loss (Pérdida):
# * La función de pérdida utilizada aquí es el mean squared error (MSE), que fue especificada durante la compilación del modelo.
# * Mide el promedio de los cuadrados de los errores entre las predicciones y los valores reales.
#
# 2. Root Mean Squared Error (RMSE):
# * Esta métrica calcula la raíz cuadrada del error cuadrático medio.
# * RMSE es una medida de la dispersión de las predicciones del modelo con respecto a los valores reales.
# * Es útil porque tiene la misma unidad de medida que la variable objetivo y es más interpretable que el MSE en términos de magnitud de los errores.
#
# 3. Mean Absolute Percentage Error (MAPE):
# * Esta métrica calcula el error porcentual absoluto medio.
# * MAPE es útil para entender el error relativo en términos porcentuales, lo que es interpretativamente beneficioso, especialmente cuando los valores de la variable objetivo tienen diferentes magnitudes.
#
# Estas métricas permiten evaluar diferentes aspectos del rendimiento del modelo:
#
# * Loss (MSE): Da una medida global de la calidad de las predicciones del modelo.
# * RMSE: Proporciona una interpretación más directa del error en las mismas unidades que la variable objetivo.
# * MAPE: Ofrece una perspectiva del error en términos porcentuales, lo que puede ser más comprensible cuando los valores objetivo varían significativamente.
#
# ## Cuántas epocas se utilizan para entrenar el modelo y por qué se elige este número?
#
# Se usan 10 epocas, se usa este número para evitar sobre ajuste del modelo.
#
# * Si la pérdida de validación comienza a aumentar mientras la pérdida de entrenamiento sigue disminuyendo, esto puede ser una señal de sobreajuste.
#
# * Si el modelo sigue mejorando significativamente en la pérdida de validación hacia la época 10, puede ser útil entrenar durante más épocas.
